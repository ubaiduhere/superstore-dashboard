# %%
# %pip install streamlit pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import streamlit as st
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from datetime import datetime

# %% [markdown]
# Data inspection

# %%
df=pd.read_csv(r"C:\Users\ubaidu\OneDrive\Desktop\sem2\project 4.1\Data\samplesuperstore.csv")

# %%
df.shape
# Out:
# (10194, 24)

# %%
df.dtypes
# Out:
# row_id              int64
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_id        object
# customer_name      object
# segment            object
# country_region     object
# city               object
# state_province     object
# postal_code        object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales             float64
# quantity            int64
# discount          float64
# profit            float64
# shipping_days       int64
# profit_margin     float64
# order_year          int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# row_id            0
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_id       0
# customer_name     0
# segment           0
# country_region    0
# city              0
# state_province    0
# postal_code       0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_days     0
# profit_margin     0
# order_year        0
# dtype: int64

# %%
print(df[["sales","profit","quantity","discount"]].describe())
# Out:
#               sales        profit      quantity      discount
# count  10194.000000  10194.000000  10194.000000  10194.000000
# mean     228.225854     28.673417      3.791838      0.155385
# std      619.906839    232.465115      2.228317      0.206249
# min        0.444000  -6599.978000      1.000000      0.000000
# 25%       17.220000      1.760800      2.000000      0.000000
# 50%       53.910000      8.690000      3.000000      0.200000
# 75%      209.500000     29.297925      5.000000      0.200000
# max    22638.480000   8399.976000     14.000000      0.800000

# %%
df.head()
# Out:
#    row_id        order_id  order_date   ship_date       ship_mode customer_id  \
# 0       1  US-2023-103800  2023-01-03  2023-01-07  Standard Class    DP-13000
# 1       2  US-2023-112326  2023-01-04  2023-01-08  Standard Class    PO-19195
# 2       3  US-2023-112326  2023-01-04  2023-01-08  Standard Class    PO-19195
# 3       4  US-2023-112326  2023-01-04  2023-01-08  Standard Class    PO-19195
# 4       5  US-2023-141817  2023-01-05  2023-01-12  Standard Class    MB-18085
#
#    customer_name      segment country_region          city  ...  \
# 0  Darren Powers     Consumer  United States       Houston  ...
# 1  Phillina Ober  Home Office  United States    Naperville  ...
# 2  Phillina Ober  Home Office  United States    Naperville  ...
# 3  Phillina Ober  Home Office  United States    Naperville  ...
# 4     Mick Brown     Consumer  United States  Philadelphia  ...
#
#           category sub_category  \
# 0  Office Supplies        Paper
# 1  Office Supplies      Binders
# ...

# %% [markdown]
# data cleaning

# %%
print("duplicate rows:",df.duplicated().sum())
dupes=df[df.duplicated(subset=["order_id"],keep=False)]
print(dupes.shape)
dupes.head()
# Out:
# duplicate rows: 0
# (7601, 24)
#    row_id        order_id  order_date   ship_date       ship_mode customer_id  \
# 1       2  US-2023-112326  2023-01-04  2023-01-08  Standard Class    PO-19195
# 2       3  US-2023-112326  2023-01-04  2023-01-08  Standard Class    PO-19195
# 3       4  US-2023-112326  2023-01-04  2023-01-08  Standard Class    PO-19195
# 5       6  US-2023-167199  2023-01-06  2023-01-10  Standard Class    ME-17320
# 6       7  US-2023-167199  2023-01-06  2023-01-10  Standard Class    ME-17320
#
#    customer_name      segment country_region        city  ...  \
# 1  Phillina Ober  Home Office  United States  Naperville  ...
# 2  Phillina Ober  Home Office  United States  Naperville  ...
# 3  Phillina Ober  Home Office  United States  Naperville  ...
# 5  Maria Etezadi  Home Office  United States   Henderson  ...
# 6  Maria Etezadi  Home Office  United States   Henderson  ...
#
#           category sub_category                                product_name  \
# ...

# %%
df["order_date"]=pd.to_datetime(df["order_date"])
df["ship_date"]=pd.to_datetime(df["ship_date"])
df["Shipping_days"]=(df["ship_date"] - df["order_date"]).dt.days

# %%
print(df.groupby("region")["Shipping_days"].mean().round(1))
# Out:
# region
# Central    4.1
# East       3.9
# South      4.0
# West       3.9
# Name: Shipping_days, dtype: float64

# %%
df["profit Margin"]= df["profit"] / df["sales"]*100
df["profit Margin"] = df["profit Margin"].round(2)
print(df.groupby("sub_category")["profit Margin"].mean().round(2))
# Out:
# sub_category
# Accessories    21.82
# Appliances    -14.90
# Art            25.22
# Binders       -19.46
# Bookcases     -13.51
# Chairs          4.71
# Copiers        32.04
# Envelopes      42.35
# Fasteners      30.63
# Furnishings    13.98
# Labels         42.46
# Machines       -6.89
# Paper          42.50
# Phones         12.25
# Storage         9.08
# Supplies       11.44
# Tables        -14.02
# Name: profit Margin, dtype: float64

# %%
df["order Year"]=df["order_date"].dt.year

# %%
df.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country_region', 'city',
#        'state_province', 'postal_code', 'region', 'product_id', 'category',
#        'sub_category', 'product_name', 'sales', 'quantity', 'discount',
#        'profit', 'shipping_days', 'profit_margin', 'order_year',
#        'Shipping_days', 'profit Margin', 'order Year'],
#       dtype='object')

# %%
df.rename(
    columns={
        "Row ID": "row_id",
        "Order ID": "order_id",
        "Order Date": "order_date",
        "Ship Date": "ship_date",
        "Ship Mode": "ship_mode",
        "Customer ID": "customer_id",
        "Customer Name": "customer_name",
        "Segment": "segment",
        "Country/Region": "country_region",
        "City": "city",
        "State/Province": "state_province",
        "Postal Code": "postal_code",
        "Region": "region",
        "Product ID": "product_id",
        "Category": "category",
        "Sub-Category": "sub_category",
        "Product Name": "product_name",
        "Sales": "sales",
        "Quantity": "quantity",
        "Discount": "discount",
        "Profit": "profit",
        "Shipping Time": "shipping_time",
        "Shipping_days": "shipping_days",
        "Profit Margin": "profit_margin",
        "Order Year": "order_year"
    },
    inplace=True
)

# %%
df.to_csv(r"C:\Users\ubaidu\OneDrive\Desktop\sem2\project 4.1\Data\samplesuperstore.csv", index=False)
